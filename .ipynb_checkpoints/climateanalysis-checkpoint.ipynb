# %%
# %matplotlib inline
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import datetime as dt

# %% [markdown]
# # Reflect Tables into SQLAlchemy ORM

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func, inspect

# %%
engine = create_engine("sqlite:///Resources/hawaii.sqlite")

# %%
# Reflect an existing database into a new model
Base = automap_base()

# Reflect the tables
Base.prepare(engine, reflect=True)

# %%
# We can view all of the classes that automap found
Base.classes.keys()
# Out:
# ['measurement', 'station']

# %%
# Save references to each table
Measurement = Base.classes.measurement
Station = Base.classes.station

# %%
# Create our session (link) from Python to the DB
session = Session(engine)
inspector = inspect(engine)

# %%
## Checking the data-Inspector
columns = inspector.get_columns('Measurement')
for column in columns:
        print(column["name"], column["type"])
# Out:
# id INTEGER
# station TEXT
# date TEXT
# prcp FLOAT
# tobs FLOAT

# %%
## Checking the data-Inspector
columns = inspector.get_columns('Station')
for column in columns:
        print(column["name"], column["type"])
# Out:
# id INTEGER
# station TEXT
# name TEXT
# latitude FLOAT
# longitude FLOAT
# elevation FLOAT

# %%
## Checking the data-Session
for row in session.query(Measurement).limit(5).all():
        print(row.date)
# Out:
# 2010-01-01
# 2010-01-02
# 2010-01-03
# 2010-01-04
# 2010-01-06

# %%
## Checking the data-Session
for row in session.query(Station).limit(5).all():
        print(row.station)
# Out:
# USC00519397
# USC00513117
# USC00514830
# USC00517948
# USC00518838

# %% [markdown]
# # Exploratory Climate Analysis

# %%
# Design a query to retrieve the last 12 months of precipitation data and plot the results
last_date_year= session.query(Measurement.date).order_by(Measurement.date.desc()).first()
print(last_date_year)
# Out:
# ('2017-08-23',)

# %%
# Calculate the date 1 year ago from the last data point in the database
year_ago = dt.date(2017, 8, 23) - dt.timedelta(days=365)
print(year_ago)
# Out:
# 2016-08-23

# %%
# Perform a query to retrieve the data and precipitation scores
scores = session.query(Measurement.date,Measurement.prcp).filter(Measurement.date <= dt.date(2017, 8, 23),Measurement.date >= dt.date(2016, 8, 23)).all()
print(scores)
# Out:
# [('2016-08-23', 0.0), ('2016-08-24', 0.08), ('2016-08-25', 0.08), ('2016-08-26', 0.0), ('2016-08-27', 0.0), ('2016-08-28', 0.01), ('2016-08-29', 0.0), ('2016-08-30', 0.0), ('2016-08-31', 0.13), ('2016-09-01', 0.0), ('2016-09-02', 0.0), ('2016-09-03', 0.0), ('2016-09-04', 0.03), ('2016-09-05', None), ('2016-09-06', None), ('2016-09-07', 0.05), ('2016-09-08', 0.0), ('2016-09-09', 0.03), ('2016-09-10', 0.0), ('2016-09-11', 0.05), ('2016-09-12', 0.0), ('2016-09-13', 0.02), ('2016-09-14', 1.32), ('2016-09-15', 0.42), ('2016-09-16', 0.06), ('2016-09-17', 0.05), ('2016-09-18', 0.0), ('2016-09-19', 0.0), ('2016-09-20', 0.0), ('2016-09-21', 0.0), ('2016-09-22', 0.02), ('2016-09-23', 0.0), ('2016-09-24', 0.0), ('2016-09-25', 0.0), ('2016-09-26', 0.06), ('2016-09-27', 0.02), ('2016-09-28', 0.0), ('2016-09-29', 0.0), ('2016-09-30', 0.0), ('2016-10-01', 0.0), ('2016-10-02', 0.0), ('2016-10-03', 0.0), ('2016-10-04', 0.0), ('2016-10-05', 0.0), ('2016-10-06', 0.0), ('2016-10-07', 0.0), ('2016-10-08'
# ...

# %%
# Save the query results as a Pandas DataFrame and set the index to the date column
scores_df= pd.DataFrame(scores)
scores_df.head()
scores_df.set_index("date", inplace=True)

# %%
# Sort the dataframe by date
scores_date_df = scores_df.sort_index()
scores_date_df
# Out:
#             prcp
# date
# 2016-08-23  0.00
# 2016-08-23   NaN
# 2016-08-23  1.79
# 2016-08-23  0.05
# 2016-08-23  0.15
# ...          ...
# 2017-08-22  0.00
# 2017-08-23  0.00
# 2017-08-23  0.00
# 2017-08-23  0.08
# 2017-08-23  0.45
#
# [2230 rows x 1 columns]

# %%
# Use Pandas to calculate the summary statistics for the precipitation data
scores_date_df.describe()
# Out:
#               prcp
# count  2021.000000
# mean      0.177279
# std       0.461190
# min       0.000000
# 25%       0.000000
# 50%       0.020000
# 75%       0.130000
# max       6.700000

# %%
# Use Matplotlib to plot the data
precipitation = scores_date_df.prcp.tolist()

plt.figure(figsize= (10, 6))
plt.bar(scores_date_df.index, precipitation, color= "C", alpha= 0.5, width= 3, linewidth= 3)

plt.xlabel("date")
plt.ylabel("inches")
plt.legend(["precipitation"], loc="upper right")

plt.xticks(scores_date_df.index[::250], rotation="90")
plt.tight_layout()
plt.show()

# %%
# Design a query to show how many stations are available in this dataset?
Station_query = session.query(Station.station).all()
Station_query
# Out:
# [('USC00519397'),
#  ('USC00513117'),
#  ('USC00514830'),
#  ('USC00517948'),
#  ('USC00518838'),
#  ('USC00519523'),
#  ('USC00519281'),
#  ('USC00511918'),
#  ('USC00516128')]

# %%
Station_count = session.query(Station.station).count()
Station_count
print(f"There are 9 stations.")
# Out:
# There are 9 stations.

# %%
# What are the most active stations? (i.e. what stations have the most rows)?
# List the stations and the counts in descending order.

active_stations = session.query(Measurement.station, func.count(Measurement.id)).group_by(Measurement.station).order_by(func.count(Measurement.station).desc()).all()
active_stations
# Out:
# [('USC00519281', 2772),
#  ('USC00519397', 2724),
#  ('USC00513117', 2709),
#  ('USC00519523', 2669),
#  ('USC00516128', 2612),
#  ('USC00514830', 2202),
#  ('USC00511918', 1979),
#  ('USC00517948', 1372),
#  ('USC00518838', 511)]

# %%
# Using the station id from the previous query, calculate the lowest temperature recorded, 
# highest temperature recorded, and average temperature of the most active station?
# TOBS
temps= session.query(Measurement.station, func.min(Measurement.tobs), func.max(Measurement.tobs)).group_by(Measurement.station).filter(Measurement.station == 'USC00519281').all()
temps
# Out:
# [('USC00519281', 54.0, 85.0)]

# %%
print(f"The lowest temp is 54.0 and the highest temp is 85.0.")
# Out:
# The lowest temp is 54.0 and the highest temp is 85.0.

# %%
# Choose the station with the highest number of temperature observations.
# Query the last 12 months of temperature observation data for this station and plot the results as a histogram

tobs_station= "USC00519281"
tobs= session.query((Measurement.tobs), func.count(Measurement.tobs)).group_by(Measurement.tobs).filter(Measurement.station == tobs_station).filter(Measurement.date <= dt.date(2017, 8, 23),Measurement.date >= dt.date(2016, 8, 23)).all()
tobs
# Out:
# [(59.0, 3),
#  (60.0, 2),
#  (61.0, 1),
#  (62.0, 6),
#  (63.0, 4),
#  (64.0, 3),
#  (65.0, 7),
#  (66.0, 5),
#  (67.0, 15),
#  (68.0, 12),
#  (69.0, 19),
#  (70.0, 22),
#  (71.0, 18),
#  (72.0, 22),
#  (73.0, 18),
#  (74.0, 39),
#  (75.0, 33),
#  (76.0, 33),
#  (77.0, 31),
#  (78.0, 22),
#  (79.0, 18),
#  (80.0, 11),
#  (81.0, 4),
#  (82.0, 3),
#  (83.0, 1)]

# %%
tobs_df= pd.DataFrame(tobs, columns= ['tobs', 'count'])
tobs_df.head()
# Out:
#    tobs  count
# 0  59.0      3
# 1  60.0      2
# 2  61.0      1
# 3  62.0      6
# 4  63.0      4

# %%
# trying DF with index for Histogram

tobs_df.set_index("tobs", inplace=True)
tobs_new_df = tobs_df.sort_index()
tobs_new_df
# Out:
#       count
# tobs
# 59.0      3
# 60.0      2
# 61.0      1
# 62.0      6
# 63.0      4
# 64.0      3
# 65.0      7
# 66.0      5
# 67.0     15
# 68.0     12
# 69.0     19
# 70.0     22
# 71.0     18
# 72.0     22
# 73.0     18
# 74.0     39
# 75.0     33
# 76.0     33
# 77.0     31
# 78.0     22
# 79.0     18
# 80.0     11
# 81.0      4
# 82.0      3
# 83.0      1

# %%
# Histogram

## Can't figure out why this is showing incorrectly

plt.figure(figsize= (10, 6))
plt.hist(tobs_new_df.index, bins=12, color= "M", alpha= 0.5)
plt.title("temperature vs count for USC00519281")
plt.xlabel("temperature")
plt.ylabel("count")
plt.legend(["tobs"], loc="upper left")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Bonus Challenge Assignment

# %%
# This function called `calc_temps` will accept start date and end date in the format '%Y-%m-%d' 
# and return the minimum, average, and maximum temperatures for that range of dates
def calc_temps(start_date, end_date):
    """TMIN, TAVG, and TMAX for a list of dates.
    
    Args:
        start_date (string): A date string in the format %Y-%m-%d
        end_date (string): A date string in the format %Y-%m-%d
        
    Returns:
        TMIN, TAVE, and TMAX
    """
    
    return session.query(func.min(Measurement.tobs), func.avg(Measurement.tobs), func.max(Measurement.tobs)).\
        filter(Measurement.date >= start_date).filter(Measurement.date <= end_date).all()

# function usage example
print(calc_temps('2012-02-28', '2012-03-05'))
# Out:
# [(62.0, 69.57142857142857, 74.0)]

# %%
# Use your previous function `calc_temps` to calculate the tmin, tavg, and tmax 
# for your trip using the previous year's data for those same dates.

# Trip dates: 03/16/2017-04/01/2017

temp_df = pd.DataFrame(calc_temps('2017-03-16', '2017-04-01'), columns=['tmin','tavg','tmax'])
temp_df
# Out:
#    tmin       tavg  tmax
# 0  65.0  73.679612  80.0

# %%
# Plot the results from your previous query as a bar chart. 
# Use "Trip Avg Temp" as your Title
# Use the average temperature for the y value
# Use the peak-to-peak (tmax-tmin) value as the y error bar (yerr)

temp_df.plot.bar(y='tavg', color= 'y', alpha= 0.5)
plt.errorbar(x=0, y=float(temp_df['tavg']), yerr=(float(temp_df['tmax']-float(temp_df['tmin']))), ecolor='m')

plt.title('trip temp average')
plt.xlabel('trip')
plt.ylabel('temp')
plt.legend('temp average', loc='upper left')
plt.tight_layout()
plt.show()

# %%
# Calculate the total amount of rainfall per weather station for your trip dates using the previous year's matching dates.
# Sort this in descending order by precipitation amount and list the station, name, latitude, longitude, and elevation

# Trip dates: 03/16/2017-04/01/2017

trip_rainfall = session.query(func.sum(Measurement.prcp), Measurement.station, Station.name, Station.latitude, 
                        Station.longitude, Station.elevation).filter(Measurement.station == Station.station).filter(Measurement.date <= dt.date(2017, 4, 1),Measurement.date >= dt.date(2017, 3, 16)).group_by(Measurement.station).order_by(func.sum(Measurement.prcp).desc()).all()
trip_rainfall
# Out:
# [(1.63,
#   'USC00516128',
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  (1.56,
#   'USC00519281',
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  (1.03, 'USC00513117', 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  (0.95,
#   'USC00519523',
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   21.33556,
#   -157.71139,
#   19.5),
#  (0.27,
#   'USC00514830',
#   'KUALOA RANCH HEADQUARTERS 886.9, HI US',
#   21.5213,
#   -157.8374,
#   7.0),
#  (0.02, 'USC00519397', 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  (0.0, 'USC00517948', 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9)]

# %%
trip_rainfall_df = pd.DataFrame(trip_rainfall, columns= ['prcp', 'station', 'name', 'lat', 'lng', 'elevation'])
trip_rainfall_df.head()
# Out:
#    prcp      station                                    name       lat  \
# 0  1.63  USC00516128            MANOA LYON ARBO 785.2, HI US  21.33310
# 1  1.56  USC00519281                     WAIHEE 837.5, HI US  21.45167
# 2  1.03  USC00513117                    KANEOHE 838.1, HI US  21.42340
# 3  0.95  USC00519523      WAIMANALO EXPERIMENTAL FARM, HI US  21.33556
# 4  0.27  USC00514830  KUALOA RANCH HEADQUARTERS 886.9, HI US  21.52130
#
#          lng  elevation
# 0 -157.80250      152.4
# 1 -157.84889       32.9
# 2 -157.80150       14.6
# 3 -157.71139       19.5
# 4 -157.83740        7.0

# %%
# Create a query that will calculate the daily normals 
# (i.e. the averages for tmin, tmax, and tavg for all historic data matching a specific month and day)

def daily_normals(date):
    """Daily Normals.
    
    Args:
        date (str): A date string in the format '%m-%d'
        
    Returns:
        A list of tuples containing the daily normals, tmin, tavg, and tmax
    
    """
    
    sel = [func.min(Measurement.tobs), func.avg(Measurement.tobs), func.max(Measurement.tobs)]
    return session.query(*sel).filter(func.strftime("%m-%d", Measurement.date) == date).all()
    
daily_normals("01-01")
# Out:
# [(62.0, 69.15384615384616, 77.0)]

# %%
# calculate the daily normals for your trip
# push each tuple of calculations into a list called `normals`

# Set the start and end date of the trip

# Use the start and end date to create a range of dates

# Stip off the year and save a list of %m-%d strings

# Loop through the list of %m-%d strings and calculate the normals for each date

# %%
# Load the previous query results into a Pandas DataFrame and add the `trip_dates` range as the `date` index

# %%
# Plot the daily normals as an area plot with `stacked=False`
